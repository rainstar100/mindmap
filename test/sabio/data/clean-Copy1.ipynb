# %%
import pandas as pd

# %%
df=pd.read_csv('brenda_combine_csv.csv')

# %%
df
# Out:
#        Unnamed: 0 TURNOVER NUMBER [1/s]          SUBSTRATE   \
# 0             NaN                  0.095  3-oxooctanoyl-CoA
# 1             NaN                  0.014    acetoacetyl-CoA
# 2             NaN                  0.019    acetoacetyl-CoA
# 3             NaN                   91.4    acetoacetyl-CoA
# 4             NaN                  102.0    acetoacetyl-CoA
# ...           ...                    ...                ...
# 36368         NaN                  0.289                ATP
# 36369         NaN                  447.0                ATP
# 36370         NaN                  674.0                ATP
# 36371         NaN                  674.0                ATP
# 36372         NaN                  0.078                ATP
#
#                          ORGANISM   UNIPROT   \
# 0      Mycolicibacterium smegmatis    P71534
# 1            Plasmodium falciparum    Q965D6
# 2      Mycolicibacterium smegmatis    P71534
# 3         Saccharomyces cerevisiae    P35731
# 4              Cupriavidus necator    P14697
# ...                            ...       ...
# 36368             Escherichia coli    B7UMA6
# 36369         Pseudomonas syringae    Q8RK01
# 36370       Legionella pneumophila    O52185
# 36371       Legionella pneumophila    O52185
# 36372                   Bos taurus    Q8HXQ5
#
#                                              COMMENTARY    LITERATURE   \
# 0                                           pH 7.0, 25°C        762566
# 1                                                 pH 7.5        654432
# 2                                           pH 7.0, 25°C        762566
# 3                 mutant enzyme S40A, at pH 8.0 and 25°C        740558
# 4                   wild type enzyme, at pH 8.0 and 30°C        739901
# ...                                                  ...           ...
# 36368                                 at pH 8.5 and 25°C        749486
# 36369                     pH 8.0, 30°C, dodecameric form        656142
# 36370                   pH 8.0, 22°C, recombinant enzyme        752136
# 36371  subunit DotBL, at 25°C, pH not specified in th...        752136
# 36372  pH and temperature not specified in the public...        747475
#
#         IMAGE   Unnamed: 8
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ...        ...         ...
# 36368      NaN         NaN
# 36369      NaN         NaN
# 36370      NaN         NaN
# 36371      NaN         NaN
# 36372      NaN         NaN
#
# [36373 rows x 9 columns]

# %%
columns=['ECNumber','Organism','Smiles','Substrate','Sequence','Value','Unit','UniprotID']

# %%
data=pd.DataFrame(columns=columns)

# %%
data['ECNumber']=df_kcat['ECNumber']
data['Organism']=df_kcat['Organism']
data['Substrate']=df_kcat['Substrate']
data['Value']=df_kcat['parameter.startValue']
data['Unit']=df_kcat['parameter.unit']
data['UniprotID']=df_kcat['UniprotID']

# %%
del data['unit']

# %%
data
# Out:
#      ECNumber                  Organism Smiles  \
# 2     1.1.1.1              Homo sapiens    NaN
# 3     1.1.1.1              Homo sapiens    NaN
# 6     1.1.1.1              Homo sapiens    NaN
# 9     1.1.1.1      Kluyveromyces lactis    NaN
# 15    1.1.1.1      Kluyveromyces lactis    NaN
# ...       ...                       ...    ...
# 3498  1.1.1.1             Moraxella sp.    NaN
# 3507  1.1.1.1             Moraxella sp.    NaN
# 3549  1.1.1.1  Saccharomyces cerevisiae    NaN
# 3553  1.1.1.1  Saccharomyces cerevisiae    NaN
# 3579  1.1.1.1  Saccharomyces cerevisiae    NaN
#
#                            Substrate Sequence       Value    Unit UniprotID
# 2                     NAD+;1-Octanol      NaN    2.833333  s^(-1)    P11766
# 3                    NAD+;1-Pentanol      NaN    0.183333  s^(-1)    P11766
# 6     12-Hydroxydodecanoic acid;NAD+      NaN    0.333333  s^(-1)    P11766
# 9                       NAD+;Ethanol      NaN  408.333300  s^(-1)    P49384
# 15                      Ethanol;NAD+      NaN  405.000000  s^(-1)    P49384
# ...                              ...      ...         ...     ...       ...
# 3498                    Ethanol;NAD+      NaN    1.663333  s^(-1)    P81786
# 3507                 H+;NADH;Acetone      NaN    0.138333  s^(-1)    P81786
# 3549            NADH;H+;Acetaldehyde      NaN  176.000000  s^(-1)    P00330
# 3553            NADH;Acetaldehyde;H+      NaN  176.000000  s^(-1)    P00330
# 3579            H+;Acetaldehyde;NADH      NaN    0.000000  s^(-1)    P38113
#
# [517 rows x 8 columns]

# %%
[1,2]==[2,1]
# Out:
# False

# %%
a='1,2'
set(a.split(','))
# Out:
# {'1', '2'}

# %%
'NAD+;Ethanol'.s=='Ethanol;NAD+'.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 'NAD+;Ethanol'.sort()=='Ethanol;NAD+'.sort()
#
# AttributeError: 'str' object has no attribute 'sort'
